# %% [markdown]
# ## First steps in PIV analysis with OpenPIV

# %% [markdown]
# ### Install what is necessary, once

# %%
# # marks a comment line in Python
# Uncomment the line below to install required packages
# !pip install numpy scipy matplotlib imageio imagecodecs pandas openpiv

# %% [markdown]
# ### test if openpiv is installed

# %%
import openpiv

# %% [markdown]
# ### run firs PIV test case

# %%
from openpiv.piv import simple_piv

# %% [markdown]
# ### we need two images to play with, see in the img/ folder

# %%
from openpiv.tools import imread
im1 = imread('../img/case1/ij_47_001_005_b.bmp')
im2 = imread('../img/case1/ij_47_001_005_c.bmp')

# %%
simple_piv(im1, im2);
